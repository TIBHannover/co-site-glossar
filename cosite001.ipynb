# %% [raw]
# ---
# title: "Co-Site Glossar"
# jupyter: python3
# code-fold: true
# execute:
#   echo: false
#   output: asis
# ---

# %% [markdown]
# Dieses Glossar enthält wichtige Begriffe des Projekts [Co-Site](index.qmd) rund um Klimawandelanpassung und unser Reallabor.

# %%
from datetime import datetime
import sys
import time
import requests
import html
import locale

locale.setlocale(locale.LC_ALL,"") 
#locale "de_DE" needs to be set as default on whichever system you run this notebook on
#otherwise the umlaute sorting won't work


api_url = "https://climatekg.semanticclimate.net/api.php"

def fetch_mediawiki_data(api_url, params, session):
    try:
        response = session.get(api_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from MediaWiki API: {e}")
        return None

def extract_items(data):
    items = []
    results = data.get("query", {}).get("results", {})
    
    for item_id, item_data in results.items():
        #print(item_data)
        #print()
        

        multilang_fields = ["description"]
        entity_fields = ["subCategoryOf", "synonyms","tags", "similarTo"]
        txt_fields = ["term","description_plain","vocabulary","acronym","status"]
        item = {
            "id": item_id
        }

        for fieldname in txt_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                item[fieldname] = item_data["printouts"].get(fieldname, [None])[0]
            else:
                item[fieldname] = ""

        for fieldname in entity_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                entities = item_data["printouts"].get(fieldname, [])
                # Check if entity is a dictionary and has the 'fulltext' key
                item[fieldname] = ", ".join(
                    [entity.get('fulltext', '') if isinstance(entity, dict) else str(entity) for entity in entities]
                )
    
                # Create a list of individual links
                links = [
                    f"[{entity.get('fulltext', '').replace('/*in', ':in').replace('*in', ':in')}](#{entity.get('fulltext', '').lower().replace(' ', '-').replace('/*', '').replace('*', '')})"
                #https://tibhannover.github.io/co-site-glossar/cosite001.html
                    if isinstance(entity, dict)
                    else f"[{str(entity).replace('/*in', ':in').replace('*in', ':in')}](#{str(entity).lower().replace(' ', '-').replace('/*', ':').replace('*', '')})"
                    for entity in entities
                ]
                                
                # Join the links with commas
                item[f"{fieldname}_links"] = ", ".join(links)
            else:
                item[fieldname] = ""
                item[f"{fieldname}_links"] = ""


        for fieldname in multilang_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                #print(fieldname)
                item[fieldname] = item_data["printouts"].get(fieldname, [{}])[0].get("Text", {}).get("item", [None])[0]
            else:
                item[fieldname] = ""
        
        if item["status"]:
            translate = {
                "Draft":"Entwurf",
                "Pending Review":"Review ausstehend",
                "Published":"Veröffentlicht",
                "Unpublished":"Unveröffentlicht"
            }
            for t in translate:
                if item["status"] == t:
                    item["status"] = translate[t]
        items.append(item)
    
    return items

#creates link to tag overview
def tag_to_link(tag):
    link = ""
    if ", " in tag:
        for i, tag in enumerate(tag.split(", ")):
            link += f'<a href="/cosite002.html#{tag.lower().replace(" ", "-").replace("/*", "").replace("*", "")}">{tag.replace("/*in", ":in").replace("*in", ":in")}</a>, '
    else:
        link += f'<a href="/cosite002.html#{tag.lower().replace(" ", "-").replace("/*", "").replace("*", "")}">{tag.replace("/*in", ":in").replace("*in", ":in")}</a>'
    return link.removesuffix(', ')


def generate_html_span(items, vocabulary):
    items = sorted(items, key=lambda t: locale.strxfrm(t['term']))
    html = '''

---

    '''      
    for item in items:  

        html +=f'''

### <span style="display: inline-flex" class="gloss-term-all gloss-term">{item["term"].replace('/*in', ':in').replace('*in', ':in')}</span>

```{{=latex}}
\\nopagebreak
\penalty 100000  
```
        '''

        if item.get("acronym"):
            html += f'''
**<span style="display: inline-flex" class="gloss-term-all gloss-acronym">({item["acronym"]})</span>**

```{{=latex}}
\\nopagebreak
\penalty 100000 
```
            '''

        html+=f'''

<span class="gloss-term-all gloss-definition">{item["description"].replace('/*in', ':in').replace('*in', ':in')}</span>
        
```{{=latex}}
\\nopagebreak
\penalty 100000
```
        '''

        if item.get("description_plain"):
            html += f'''
**<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
<span class="gloss-term-all gloss-cl-definition">{item["description_plain"].replace('/*in', ':in').replace('*in', ':in')}</span>
<br>

```{{=latex}}
\\nopagebreak
\penalty 100000  
```
            ''' 

        if item.get("status"):
            html += f'''
::: {{.content-visible when-format="html"}}
**<span class="gloss-term-all gloss-status-label">Status: </span> **
<span class="gloss-term-all gloss-status">{item["status"]}</span>
<br>

:::
            '''

        if item.get("similarTo"):
            html += f'''
**<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
<span class="gloss-term-all gloss-similarto">{item["similarTo_links"]}</span>
<br>

```{{=latex}}
\\nopagebreak
\penalty 100000 
```
            '''

        if item.get("subCategoryOf"):
            html += f'''
**<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
<span class="gloss-term-all gloss-subCategoryOf">{item["subCategoryOf_links"]}</span>
<br>

```{{=latex}}
\\nopagebreak
\penalty 100000  
```
            '''

        if item.get("synonyms"):
            html += f'''
**<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme: </span> **
<span class="gloss-term-all gloss-synonym">{item['synonyms_links']}</span>
<br>

```{{=latex}}
\\nopagebreak
\penalty 100000  
```
            '''

        if item.get("tags"):
            tag = tag_to_link(item.get("tags"))
            html += f'''

::: {{.content-visible when-format="html"}}
<span class="tag-label">Tags:</span>
<span class="gloss-term-all gloss-tag">{tag}</span>
:::

::: {{.content-visible when-format="pdf"}}
*<span class="gloss-term-all gloss-tag">{tag}</span>*
:::

            '''
        html+='''
---

```{=latex}
\penalty -100  % Allow a break more easily here
```

        '''

    return html


def login(api_url, username, password):
    session = requests.Session()
    
    # Step 1: GET request to fetch login token
    login_token_params = {
        'action': 'query',
        'meta': 'tokens',
        'type': 'login',
        'format': 'json'
    }
    response = session.get(api_url, params=login_token_params)
    response.raise_for_status()
    login_token = response.json()['query']['tokens']['logintoken']
    
    # Step 2: POST request to log in
    login_params = {
        'action': 'login',
        'lgname': username,
        'lgpassword': password,
        'lgtoken': login_token,
        'format': 'json'
    }
    response = session.post(api_url, data=login_params)
    response.raise_for_status()
    login_result = response.json()
    
    if login_result['login']['result'] == 'Success':
        #print('Logged in successfully')
        return session
    else:
        print('Failed to log in')
        sys.exit(1)

def get_glossary(vocabulary, session):

    params = {
        'action': 'ask',
        'query': f'[[Item:+]] [[has subobject::+]] [[P1::Term]] [[P18::{vocabulary}]] [[P20::!Unpublished]] |?Wikibase description=description |?P26=description_plain |?P3=term |?P10.P3=subCategoryOf |?P20=status |?P21=acronym |?P22=tags |?P23.P3=similarTo |?P18=vocabulary |?P24.P3=synonyms |sort=P3 |limit=1000',
        'format': 'json'
    }

    response = fetch_mediawiki_data(api_url, params, session)
    items = extract_items(response)
    
    if items:
        # Generate the HTML for the table
        html = '<html><head><link rel="stylesheet" href="glossary.css"></head><body>\n\n'
        #html += generate_html_table(items)
        html += generate_html_span(items,vocabulary)
        html += '\n</body></html>'
        print(html)

# %%
username = 'reader'  # Replace with your username
password = 'readonly'  # Replace with your password

session = login(api_url, username, password)
get_glossary("Co-Site", session)
# Out:
# <html><head><link rel="stylesheet" href="glossary.css"></head><body>
#
#
#
# ---
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term"></span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition"></span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">360-Grad-Video</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Video, das in alle Richtungen gleichzeitig aufgenommen wird, sodass sich die Zuschauer:innen in jede Richtung umsehen können. Diese Videos bieten ein immersives Erlebnis, bei dem Betrachter:innen das Gefühl haben, mitten im Geschehen zu sein, wenn sie das Video auf einem Bildschirm oder mit einer VR-Brillen betrachten.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[VR-Brille](#vr-brille), [Immersion](#immersion)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Agenda 2030</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Die Agenda 2030 ist ein internationales Abkommen, in dem ökonomische, ökologische und soziale Ziele (Sustainable Development Goals) im Sinne einer nachhaltigen Entwicklung angestrebt werden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Sozial-ökologische Transformation](#sozial-ökologische-transformation), [Sustainable Development Goals](#sustainable-development-goals)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Agilität</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Agilität ist die Fähigkeit einer Organisation, sich schnell an Veränderungen und Ereignisse anzupassen. Dies beinhaltet Flexibilität in Strukturen, Prozessen und Arbeitsweisen, um auf neue Anforderungen und Ressourcenverfügbarkeit zu reagieren. Dadurch können kontinuierliche Verbesserungen erzielt, Herausforderungen bewältigt und das gemeinsame Zielverständnis reflektiert und angepasst werden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Akteur:innen</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Proaktiv oder aktiv handelnde Personen, Institutionen oder Organisationen im Wirkungsfeld des Reallabors oder eines Teilbereichs (Thema, Standort etc.) davon.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Akteursnetzwerkanalyse</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Eine Analyse der Beziehungen der Interessens- und Anspruchsgruppen. Sie dient zur Erfassung relevanter Akteur:innen und kann als Arbeitsgrundlage zur Einbindung dieser unterstützen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Allgemeine Weiterbildung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Allgemeine Weiterbildung bezeichnet Bildungsmaßnahmen, die sich nicht direkt auf berufliche Anforderungen beziehen, sondern darauf abzielen, die allgemeinen Kenntnisse, Fähigkeiten und das Wissen von Menschen zu erweitern. Diese Art der Weiterbildung fördert sowohl die persönliche als auch die gesellschaftliche Entwicklung und richtet sich an eine breite Zielgruppe.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Ambiguität</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Mehrdeutigkeit eines Begriffs oder Sachverhalts. Beinhaltet auch situative Unsicherheiten und entscheidungsrelevante Uneindeutigkeiten, wenn verschiedene Möglichkeiten offenstehen und eine eindeutige Antwort oder ideale Lösung nicht offensichtlich ist.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Anfälligkeit</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">siehe Vulnerabilität</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme: </span> **
# <span class="gloss-term-all gloss-synonym">[Vulnerabilität](#vulnerabilität)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Anpassungsfähigkeit</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">bezieht sich auf die Fähigkeit, verfügbare Ressourcen und Strategien, die Schäden von stressauslösenden Rahmenbedingungen und Entwicklungen zu bewältigen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gefahr">Gefahr</a>, <a href="/cosite002.html#kritis">KRITIS</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gefahr">Gefahr</a>, <a href="/cosite002.html#kritis">KRITIS</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">AR-Brille</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Eine AR-Brille (Augmented Reality-Brille) ist ein tragbares Gerät (Head-Mounted Display), das wie eine Brille getragen wird und digitale Informationen in die reale Welt einblendet. Diese Brillen projizieren virtuelle Elemente, wie Bilder oder Texte, in das Sichtfeld des Benutzers und ermöglichen so interaktive und erweiterte Erfahrungen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Augmented Reality](#augmented-reality)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Head-Mounted Display](#head-mounted-display)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Augmented Reality</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(AR)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Augmented Reality (dt. augmentierte Realität, auch erweiterte Realität genannt) bezeichnet virtuelle Inhalte, wie starre oder bewegte Objekte, die mit der realen Umgebung überlagert werden. Diese überlagerten Zusatzinformationen werden in Echtzeit von Geräten wie Smartphones, Tablets oder speziellen AR-Brillen bereitgestellt und angezeigt.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Virtual Reality](#virtual-reality)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Extended Reality](#extended-reality)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Augmented Virtuality</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(AV)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Augmented Virtuality (dt. augmentierte Virtualität) bezeichnet eine teils virtuelle Umgebung, in der reale Inhalte eingefügt werden. Dabei werden Informationen aus der realen Welt, wie zum Beispiel Objekte oder Personen, in eine virtuelle Welt integriert.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Balanced Scorecard</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(BSC)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Die Balanced Scorecard ist ein ganzheitlich orientiertes Konzept zur Messung, Dokumentation und Steuerung der Aktivitäten einer Organisation in Bezug auf ihre Vision und Strategie. Sie kombiniert Indikatoren aus verschiedenen Perspektiven und fördert dadurch die Transparenz sowie die strategische Ausrichtung der Organisation.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bedarfsanalyse</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Eine Bedarfsanalyse ermittelt systematisch Lücken und künftige Handlungsfelder in einem Themenfeld, einer Organisation oder Ziel- bzw. Dialoggruppe. Ziel ist es, basierend darauf, ziel- und themenorientierte Maßnahmen zu entwickeln und diese nachfrageorientiert anzubieten.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Prospektive Evaluation](#prospektive-evaluation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Begleitforschung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ein Synonym für formative Evaluation</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme: </span> **
# <span class="gloss-term-all gloss-synonym">[Formative Evaluation](#formative-evaluation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Berufliche Weiterbildung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Berufliche Weiterbildung bedeutet, dass eine Person nach ihrer Ausbildung zusätzliche Fähigkeiten erwirbt. Entweder, um bestehendes Wissen zu vertiefen (Fortbildung), sich auf eine höhere Position vorzubereiten (Aufstiegsweiterbildung) oder eine neue berufliche Richtung einzuschlagen (Umschulung).</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Weiterbildung](#weiterbildung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Best Practices</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Praktiken, Methoden und Verhaltensweisen, die in der Praxis zum Einsatz kommen und erprobt, verbreitet und (besonders) positiv evaluiert sind.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">In der Praxis erprobte, verbreitete und positiv evaluierte Praktiken, Methoden und Verhaltensweisen.</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Systemwissen](#systemwissen), [Zielwissen](#zielwissen), [Transformationswissen](#transformationswissen)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Practices](#practices)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Betriebliche Weiterbildung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Bei betrieblicher Weiterbildung handelt es sich um organisierte und vollständig oder teilweise vom Arbeitsgeber finanzierte Weiterbildungsmaßnahmen in unterschiedlichen Lernformaten (Lernvideos, digitale oder analoge Workshops, Hackathons, Barcamps...)</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bevölkerungsschutz</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Der Bevölkerungsschutz beschreibt als Oberbegriff alle Aufgaben und Maßnahmen der Kommunen und der Länder im Katastrophenschutz sowie des Bundes im Zivilschutz.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bewältigungskapazität</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Die Kombination aller Stärken, Eigenschaften und Ressourcen, die innerhalb einer Organisation, Gemeinschaft oder Gesellschaft vorhanden sind, um Katastrophenrisiken zu bewältigen und zu verringern und die Widerstandsfähigkeit zu stärken.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Katastrophe](#katastrophe)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bildung für Nachhaltige Entwicklung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(BNE)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Bildung, die Menschen zu zukunftsfähigem Denken und Handeln befähigt, indem sie es ermöglicht, die Auswirkungen des eigenen Handelns auf die Welt zu verstehen. Sie berücksichtigt dabei explizit planetare Grenzen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Sozial-ökologische Transformation](#sozial-ökologische-transformation), [Transformatives Lernen](#transformatives-lernen)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a>, <a href="/cosite002.html#transformatives-lernen">Transformatives Lernen</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a>, <a href="/cosite002.html#transformatives-lernen">Transformatives Lernen</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Blackout</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ungeplanter, großflächiger und langanhaltender Stromausfall.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kritis">KRITIS</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kritis">KRITIS</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Blaue Infrastruktur</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Netzwerk aus wassergeprägten Elementen, die eine Vielzahl von ökologischen, sozialen und wirtschaftlichen Funktionen bereitstellen. Strategisch werden diese z.B. zur Bewältigung von Problemen im Wasserkreislauf (z.B. Wasseraufbereitung, Dürren, Regenwasserbewirtschaftung) angelegt. Natürliche Systeme sind u.a. Seen oder Flüsse; geplante Systeme umfassen Retentionsflächen oder Flussrenaturierungen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">Wasserbezogene Infrastruktur</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Blau-grüne Infrastruktur</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(BGI)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Strategisch geplantes Netzwerk natürlicher und naturnaher Flächen bei besonderer Berücksichtigung der Wechselwirkungen mit dem natürlichen und technischen Wasserkreislauf (Wasserspeicherung, Hochwasser, Dürren, Wasseraufbereitung, Regenwasserbewirtschaftung). Primäre Elemente sind u.a. Retentionssysteme, Zisternen, Rigolen und urbane Gewässer; sekundäre Elemente sind u.a. Regengärten, Gründächer.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">Dieses Konzept kombiniert Wasserbewirtschaftung (blau) mit Vegetation (grün), um nachhaltige und resiliente städtische und ländliche Umgebungen zu schaffen.</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Infrastruktur](#infrastruktur)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Change Agents</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Personen(-gruppen), die aktiv Veränderungen im Wirkungsbereich des Reallabors initiieren oder bestehende Prozesse hinterfragen und als Vorreiter\:innen und Transformationsbeschleuniger\:innen für Stakeholder des Reallabors fungieren</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Sozial-ökologische Transformation](#sozial-ökologische-transformation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Citizen Science</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Direkte Beteiligung von Bürger\:innen am Forschungsprozess, beispielsweise beim Daten sammeln, auswerten und aufbereiten. Der Fokus liegt hierbei auf der aktiven Gestaltung und Umsetzung von Wissenschaft durch Bürger\:innen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-Design</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">aktive und methodengeleitete Einbindung relevanter Stakeholdergruppen in den Forschungs- und Entwicklungsprozess</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">Sinnvolle Einbindung verschiedener Stakeholder in Prozesse. Dies passiert methodengeleitet und bewusst, unterstützt durch schrittweise Reevaluation und Anpassung gemeinsam mit relevanten Personen(-gruppen). Um seinem Anspruch gemäß sinnvoll zu sein, muss Co-Design stark kontext-angepasst vorgehen: Einzelne Elemente variieren je nach Stakeholder, Situation, Ort, Ressourcen, etc..</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Co-Kreation](#co-kreation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-Kreation</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Gemeinschaftliche Gestaltung eines End- oder Zwischenprodukts unter Einbezug verschiedener Interessensgruppen</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-kreative Wissenschaftskommunikation</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Anhand der Kommunikationsbedürfnisse gesellschaftlicher Gruppen, wie Bürger\:innen, werden gemeinsam Inhalte sowie Formate der Wissenschaftskommunikation erdacht, produziert und entwickelt.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-kreativer Workshop</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ein methodisch strukturiertes Setting der Zusammenarbeit mehrerer Personen, welches zumeist von einer Moderation geleitet wird. Ziel ist die gemeinschaftliche Erarbeitung, Gestaltung und Entwicklung eines oder mehrer Outputs, welche sowohl abstrakter als auch gestalterischer Natur sein können.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Controller</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ein Controller ist ein Eingabegerät, das Nutzer:innen ermöglicht, Befehle und Aktionen an ein elektronisches System, beispielsweise einen Computer, zu senden. Beispiele sind Gamepads, Joysticks oder VR-Controller.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#digitale-technologien">Digitale Technologien</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#digitale-technologien">Digitale Technologien</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-Site</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Forschungsprojekt "Co-Kreation in der Region – Systematisch und innovativ Transfer entwickeln" (Co-Site) der TH Köln, das vom Bundesministerium für Bildung und Forschung (BMBF) innerhalb der Initiative Innovative Hochschule gefördert wird</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-Site-Glossar</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Das Glossar des Projekts Co-Site erläutert und beschreibt zentrale Begriffe und Konzepte, die im Kontext des Projekts verwendet werden, für alle Beteiligten verständlich. Es stellt die Basis für eine gemeinsame Kommunikation und Verständigung innerhalb des Projektes und darüber hinaus dar.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">Das Glossar des Projekts Co-Site.</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Glossar](#glossar)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Dachbegrünung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Dachbegrünung beinhaltet die Bepflanzung von Dächern und bietet ökologische, ästhetische und funktionale Vorteile. Es gibt zwei Haupttypen: extensive Begrünung und intensive Begrünung. Die Hauptvorteile sind die Verbesserung des Stadtklimas, des Wassermanagements, der Energieeffizienz und der Biodiversität sowie die Steigerung der ästhetischen Qualität und der Lebensqualität in urbanen Räumen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Extensive Dachbegrünung](#extensive-dachbegrünung), [Intensive Dachbegrünung](#intensive-dachbegrünung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Dateiformat</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Definiert, wie Daten in einer Datei organisiert und gespeichert werden, damit Software sie korrekt lesen und verarbeiten kann. Jedes Format ist spezialisiert auf bestimmte Datentypen, z.B. Texte, Videos oder Bilder. Jedes Format hat spezifische Eigenschaften und Einschränkungen. Beispiele für Dateiformaten sind:  DOCX, DOC, XLSX, XLS, PPTX, PPT, TXT, RTF, JPEG, PNG, TIFF und BMP</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#informationssystem">Informationssystem</a>, <a href="/cosite002.html#daten">Daten</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#informationssystem">Informationssystem</a>, <a href="/cosite002.html#daten">Daten</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Datenerfassung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ...
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wirkungsanalyse</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Wirkungsanalyse stellt Evaluation bezogen auf die Gesamtheit eines Projekts dar. Sie umfasst die Entwicklung von Wirkungslogiken sowie die Planung, Beschreibung und Bewertung von Auswirkungen und Wechselwirkungen des Projekts auf relevante Faktoren und Stakeholder.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wirkungsmodell</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ein Wirkungsmodell ist eine systematische, visuelle Darstellung die beschreibt welche Veränderungen und Ergebnissen durch das Projekt erzielt werden sollen und wie diese Zielreichung umgesetzt werden soll. Dabei werden Ressourcen, Rahmenbedingungen, Maßnahmen sowie direkte und indirekte Wirkungen berücksichtigt und miteinander in Verbindung gesetzt. Sie basieren oft auf dem IOOI-Modell von Phineo.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wirkungsorientierung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Wirkungsorientierung bedeutet, dass ein Projekt darauf abzielt, gesellschaftliche Veränderungen zu bewirken, und dass es dementsprechend geplant und umgesetzt wird. Der Begriff wird im Feld der Wirkungsanalyse u. a. gerne genutzt, um zu verdeutlichen, dass Wirkung nicht wirklich messbar ist.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wissenschaftliche Weiterbildung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Wissenschaftliche Weiterbildung sind Maßnahmen, die auf wissenschaftlichen Erkenntnissen und Methoden basieren, für Personen mit berufsqualifizierendem oder akademischem Abschluss. Die Lernformate sind handlungsorientiert und zielen darauf ab, Fach- und Handlungskompetenzen in spezifischen Bereichen zu vertiefen oder zu erweitern.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wissenschaftskommunikation</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(WissKomm)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Umfasst alle Aspekte der Kommunikation über wissenschaftliches Arbeiten, wissenschaftliche Aktivitäten und wissenschaftliche Ergebnisse, sowohl innerhalb der Wissenschaft als auch (im Besonderen) darüber hinaus.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wissenserzeugung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Prozess, mit dem neues Wissen generiert wird. Wissen kann auf verschiedenen Wegen erzeugt werden, zum Beispiel durch Forschung und partizipativen Austausch. Im Kontext von Reallaborarbeit bedeutet dies u. a. die Verknüpfung von vorhandenem Wissen verschiedener relevanter Stakeholder und die dadurch erzeugte ganzheitliche Erweiterung, Ergänzung und Entwicklung neuen Wissens.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wissenstransfer</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Austausch von Wissen zwischen Personen oder Institutionen, z. B. in der Gesellschaft, Politik, Wirtschaft oder Wissenschaft</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Workshop</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ein methodisch strukturiertes Setting der Zusammenarbeit mehrerer Personen, welches zumeist von einer Moderation geleitet wird. Ziele sind die begleitete Wissensaneignung oder gemeinsame Produktion von Inhalten sowie Prototypen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zeitliche Auflösung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Zeitliche Abstände zwischen einzelnen Aufnahmen des gleichen Gebietes in einem Datensatz.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zeitreihe</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Zeitlich geordnete Messdaten, die regelmäßig erfasst wurden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zielgruppe</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Eine Person oder Gruppe von Menschen, die mit den Maßnahmen des Reallabors angesprochen oder eingebunden werden sollen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Dialoggruppe](#dialoggruppe)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zielwissen</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Gemeinsam generiertes Wissen über gewünschte zukünftige Entwicklungen eines Systems</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Systemwissen](#systemwissen), [Transformationswissen](#transformationswissen)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Transformatives Lernen](#transformatives-lernen), [Vision](#vision), [Transformative Wissenschaft](#transformative-wissenschaft)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zivilschutz</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Beschreibt den Schutz der Bevölkerung durch nicht militärische Maßnahmen im Falle von militärischen Auseinandersetzungen. Zum Zivilschutz gehören insbesondere der Selbstschutz, die Warnung der Bevölkerung, der Schutzbau, die Aufenthaltsregelung, der Katastrophenschutz nach Maßgabe des § 11 ZSKG, Maßnahmen zum Schutz der Gesundheit, Maßnahmen zum Schutz von Kulturgut.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Bevölkerungsschutz](#bevölkerungsschutz)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagment">Risikomanagment</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagment">Risikomanagment</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100  % Allow a break more easily here
# ```
#
#
# </body></html>
