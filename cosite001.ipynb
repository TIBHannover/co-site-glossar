# %% [raw]
# ---
# title: "Co-Site Glossar"
# jupyter: python3
# code-fold: true
# execute:
#   echo: false
#   output: asis
# ---

# %% [markdown]
# Dieses Glossar enthält wichtige Begriffe des Projekts [Co-Site](index.qmd) rund um Klimawandelanpassung und unser Reallabor.

# %%
from datetime import datetime
import sys
import time
import requests
import html
import locale

locale.setlocale(locale.LC_ALL,"") 
#locale "de_DE" needs to be set as default on whichever system you run this notebook on
#otherwise the umlaute sorting won't work


api_url = "https://climatekg.semanticclimate.net/api.php"

def fetch_mediawiki_data(api_url, params, session):
    try:
        response = session.get(api_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from MediaWiki API: {e}")
        return None

def extract_items(data):
    items = []
    results = data.get("query", {}).get("results", {})
    
    for item_id, item_data in results.items():
        #print(item_data)
        #print()
        

        multilang_fields = ["description"]
        alias_fields = ["alias"]
        entity_fields = ["subCategoryOf", "synonyms","tags", "similarTo"]
        txt_fields = ["term","description_plain", "vocabulary","acronym","status"]
        item = {
            "id": item_id
        }

        for fieldname in txt_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                item[fieldname] = item_data["printouts"].get(fieldname, [None])[0]
            else:
                item[fieldname] = ""

        for fieldname in entity_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                entities = item_data["printouts"].get(fieldname, [])
                # Check if entity is a dictionary and has the 'fulltext' key
                item[fieldname] = ", ".join(
                    [entity.get('fulltext', '') if isinstance(entity, dict) else str(entity) for entity in entities]
                )
    
                # Create a list of individual links
                links = [
                    f"[{entity.get('fulltext', '').replace('/*in', ':in').replace('*in', ':in')}](#{entity.get('fulltext', '').lower().replace(' ', '-').replace('/*', '').replace('*', '')})"
                #https://tibhannover.github.io/co-site-glossar/cosite001.html
                    if isinstance(entity, dict)
                    else f"[{str(entity).replace('/*in', ':in').replace('*in', ':in')}](#{str(entity).lower().replace(' ', '-').replace('/*', ':').replace('*', '')})"
                    for entity in entities
                ]
                                
                # Join the links with commas
                item[f"{fieldname}_links"] = ", ".join(links)
            else:
                item[fieldname] = ""
                item[f"{fieldname}_links"] = ""

        for fieldname in alias_fields:
            aliases_nodes = item_data.get("printouts", {}).get("alias", [])
            aliases_list = []
            for n in aliases_nodes:
                if isinstance(n, dict):
                    vals = n.get("Text", {}).get("item", [])
                    if isinstance(vals, str):
                        vals = [vals]
                    aliases_list.extend(vals)
                elif isinstance(n, str):
                    aliases_list.append(n)

            item["alias"] = ", ".join(aliases_list)


        for fieldname in multilang_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                #print(fieldname)
                item[fieldname] = item_data["printouts"].get(fieldname, [{}])[0].get("Text", {}).get("item", [None])[0]
            else:
                item[fieldname] = ""
        
        if item["status"]:
            translate = {
                "Draft":"Entwurf",
                "Pending Review":"Review ausstehend",
                "Published":"Veröffentlicht",
                "Unpublished":"Unveröffentlicht"
            }
            for t in translate:
                if item["status"] == t:
                    item["status"] = translate[t]
        items.append(item)
    
    return items

#creates link to tag overview
def tag_to_link(tag):
    link = ""
    if ", " in tag:
        for i, tag in enumerate(tag.split(", ")):
            link += f'<a href="/cosite002.html#{tag.lower().replace(" ", "-").replace("/*", "").replace("*", "")}">{tag.replace("/*in", ":in").replace("*in", ":in")}</a>, '
    else:
        link += f'<a href="/cosite002.html#{tag.lower().replace(" ", "-").replace("/*", "").replace("*", "")}">{tag.replace("/*in", ":in").replace("*in", ":in")}</a>'
    return link.removesuffix(', ')


def generate_html_span(items, vocabulary):
    items = sorted(items, key=lambda t: locale.strxfrm(t['term']))
    html = '''

---

![Mind Map](/images/mindmap.jpg "Mind Map"){.lightbox}
Quelle: [Co-Site Glossar (Kumu)](https://kumu.io/co-site/co-site-glossar)
    
{{< pagebreak >}}

    '''         
    for item in items:  
        html +=f'''

### <span style="display: inline-flex" class="gloss-term-all gloss-term">{item["term"].replace('/*in', ':in').replace('*in', ':in')}</span>

```{{=latex}}
\\nopagebreak
\\penalty 100000  
```
        '''

        if item.get("acronym") and item.get("alias") :
            html += f'''
**<span style="display: inline-flex" class="gloss-term-all gloss-acronym">({item["acronym"]}, {item["alias"]})</span>**

```{{=latex}}
\\nopagebreak
\\penalty 100000 
```
        '''

        elif item.get("alias"):
            html += f'''
**<span style="display: inline-flex" class="gloss-term-all gloss-acronym">({item["alias"]})</span>**

```{{=latex}}
\\nopagebreak
\\penalty 100000 
```
            '''
        elif item.get("acronym") :
            html += f'''
**<span style="display: inline-flex" class="gloss-term-all gloss-acronym">({item["acronym"]})</span>**

```{{=latex}}
\\nopagebreak
\\penalty 100000 
```
        '''
            
        html+=f'''

<span class="gloss-term-all gloss-definition">{item["description"].replace('/*in', ':in').replace('*in', ':in')}</span>
        
```{{=latex}}
\\nopagebreak
\\penalty 100000
```
        '''

        if item.get("description_plain"):
            html += f'''
**<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
<span class="gloss-term-all gloss-cl-definition">{item["description_plain"].replace('/*in', ':in').replace('*in', ':in')}</span>
<br>

```{{=latex}}
\\nopagebreak
\\penalty 100000  
```
            ''' 

        if item.get("status"):
            html += f'''
::: {{.content-visible when-format="html"}}
**<span class="gloss-term-all gloss-status-label">Status: </span> **
<span class="gloss-term-all gloss-status">{item["status"]}</span>
<br>

:::
            '''

        if item.get("similarTo"):
            html += f'''
**<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
<span class="gloss-term-all gloss-similarto">{item["similarTo_links"]}</span>
<br>

```{{=latex}}
\\nopagebreak
\\penalty 100000 
```
            '''

        if item.get("subCategoryOf"):
            html += f'''
**<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
<span class="gloss-term-all gloss-subCategoryOf">{item["subCategoryOf_links"]}</span>
<br>

```{{=latex}}
\\nopagebreak
\\penalty 100000  
```
            '''

        if item.get("synonyms"):
            html += f'''
**<span class="gloss-term-all gloss-synonyme-tag gloss-synonyme-label">Synonyme: </span> **
<span class="gloss-term-all gloss-synonym">{item['synonyms_links']}</span>
<br>

```{{=latex}}
\\nopagebreak
\\penalty 100000  
```
            '''

        if item.get("tags"):
            tag = tag_to_link(item.get("tags"))
            html += f'''

::: {{.content-visible when-format="html"}}
<span class="tag-label">Tags:</span>
<span class="gloss-term-all gloss-tag">{tag}</span>
:::

::: {{.content-visible when-format="pdf"}}
*<span class="gloss-term-all gloss-tag">{tag}</span>*
:::

            '''
        html+='''
---

```{=latex}
\\penalty -100  
```

        '''
        
    return html


def login(api_url, username, password):
    session = requests.Session()
    
    # Step 1: GET request to fetch login token
    login_token_params = {
        'action': 'query',
        'meta': 'tokens',
        'type': 'login',
        'format': 'json'
    }
    response = session.get(api_url, params=login_token_params)
    response.raise_for_status()
    login_token = response.json()['query']['tokens']['logintoken']
    
    # Step 2: POST request to log in
    login_params = {
        'action': 'login',
        'lgname': username,
        'lgpassword': password,
        'lgtoken': login_token,
        'format': 'json'
    }
    response = session.post(api_url, data=login_params)
    response.raise_for_status()
    login_result = response.json()
    
    if login_result['login']['result'] == 'Success':
        #print('Logged in successfully')
        return session
    else:
        print('Failed to log in')
        sys.exit(1)

def get_glossary(vocabulary, session):

    params = {
        'action': 'ask',
        'query': f'[[Item:+]] [[has subobject::+]] [[P1::Term]] [[P18::{vocabulary}]] [[P20::!Unpublished]] |?Wikibase description=description |?Wikibase alias=alias |?P26=description_plain |?P3=term |?P10.P3=subCategoryOf |?P20=status |?P21=acronym |?P22=tags |?P23.P3=similarTo |?P18=vocabulary |?P24.P3=synonyms |sort=P3 |limit=1000',
        'format': 'json'
    }

    response = fetch_mediawiki_data(api_url, params, session)
    items = extract_items(response)
    
    if items:
        # Generate the HTML for the table
        html = '<html><head><link rel="stylesheet" href="glossary.css"></head><body>\n\n'
        #html += generate_html_table(items)
        html += generate_html_span(items,vocabulary)
        html += '\n</body></html>'
        print(html)

# %%
username = 'reader'  # Replace with your username
password = 'readonly'  # Replace with your password

session = login(api_url, username, password)
get_glossary("Co-Site", session)
# Out:
# <html><head><link rel="stylesheet" href="glossary.css"></head><body>
#
#
#
# ---
#
# ![Mind Map](/images/mindmap.jpg "Mind Map"){.lightbox}
# Quelle: [Co-Site Glossar (Kumu)](https://kumu.io/co-site/co-site-glossar)
#
# {{< pagebreak >}}
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">360-Grad-Video</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Video, das in alle Richtungen gleichzeitig aufgenommen wird, sodass sich die Zuschauer\:innen in jede Richtung umsehen können. Diese Videos bieten ein immersives Erlebnis: Die Betrachter\:innen haben das Gefühl, mitten im Geschehen zu sein, wenn sie das Video auf einem Bildschirm oder mit einer VR-Brille betrachten.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Head-Mounted Display](#head-mounted-display), [VR-Brille](#vr-brille), [Immersion](#immersion)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Virtual Reality](#virtual-reality)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">AR-Brille</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Tragbares Gerät, das wie eine Brille getragen wird und digitale Informationen in die reale Welt einblendet. Eine Augmented Reality-Brille (AR-Brille) projiziert virtuelle Elemente wie Bilder oder Texte in das Sichtfeld des\*der Benutzer\:in und ermöglichen so interaktive und erweiterte Erfahrungen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[VR-Brille](#vr-brille), [Eye-Tracking](#eye-tracking)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Augmented Reality](#augmented-reality), [Head-Mounted Display](#head-mounted-display)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Agenda 2030</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Internationales Abkommen, in dem ökonomische, ökologische und soziale Ziele (Sustainable Development Goals) im Sinne einer nachhaltigen Entwicklung angestrebt werden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Sozial-ökologische Transformation](#sozial-ökologische-transformation), [Vision](#vision), [Nachhaltigkeit](#nachhaltigkeit), [Nachhaltigkeitsstrategie](#nachhaltigkeitsstrategie), [Transformation](#transformation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Agilität</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Fähigkeit einer Organisation, sich schnell an Veränderungen und Ereignisse anzupassen. Dies beinhaltet Flexibilität in Strukturen, Prozessen und Arbeitsweisen, um auf neue Anforderungen und Ressourcenverfügbarkeit zu reagieren. Dadurch können kontinuierliche Verbesserungen erzielt, Herausforderungen bewältigt und das gemeinsame Zielverständnis reflektiert und angepasst werden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Anpassungsfähigkeit](#anpassungsfähigkeit), [VUCA](#vuca)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Resilienz](#resilienz)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Akteur:innen</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Proaktiv oder aktiv handelnde Personen, Institutionen oder Organisationen im Wirkungsfeld des Reallabors oder eines Teilbereichs davon (z. B. Thema, Standort etc.)</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Transformationsnetzwerk](#transformationsnetzwerk), [Transferbeirat](#transferbeirat), [Transdisziplinäres Arbeiten](#transdisziplinäres-arbeiten), [Partner\:innen](#partner\innen)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Akteursnetzwerkanalyse</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Analyse der Beziehungen von Interessens- und Anspruchsgruppen. Sie dient der Erfassung relevanter Akteur\:innen und kann als Arbeitsgrundlage zu deren Einbindung unterstützen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Partizipation](#partizipation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Akteur:innen](#akteurinnen)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Allgemeine Weiterbildung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Umfasst Bildungsangebote zur Erweiterung von Wissen und Fähigkeiten in diversen Bereichen, unabhängig vom beruflichen Kontext (z. B. Sprache, Technik und Musik). Diese Art der Weiterbildung fördert sowohl die persönliche als auch die gesellschaftliche Entwicklung und ist offen für alle Interessierte.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Berufliche Weiterbildung](#berufliche-weiterbildung), [Wissenschaftliche Weiterbildung](#wissenschaftliche-weiterbildung), [Betriebliche Weiterbildung](#betriebliche-weiterbildung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Weiterbildung](#weiterbildung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Ambiguität</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Mehrdeutigkeit eines Begriffs oder Sachverhalts. Beinhaltet auch situative Unsicherheiten und entscheidungsrelevante Uneindeutigkeiten, wenn verschiedene Möglichkeiten offenstehen und eine eindeutige Antwort oder ideale Lösung nicht offensichtlich ist.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[VUCA](#vuca)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Anpassungsfähigkeit</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Fähigkeit, sich ändernden Rahmenbedingungen (z. B. klimatischen Veränderungen) und Ereignissen (z. B. Naturkatastrophen) anzupassen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Agilität](#agilität), [Future Skills](#future-skills), [Katastrophe](#katastrophe), [Transformatives Lernen](#transformatives-lernen), [Härtung](#härtung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Resilienz](#resilienz), [Klimarisiko](#klimarisiko)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Augmented Reality</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(AR, Augmentierte Realität, Erweiterte Realität)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Virtuelle Inhalte, wie starre oder bewegte Objekte, die die reale Umgebung überlagern. Diese überlagerten Zusatzinformationen werden in Echtzeit von Geräten wie Smartphones, Tablets oder speziellen AR-Brillen bereitgestellt und angezeigt.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Virtual Reality](#virtual-reality), [AR-Brille](#ar-brille), [Augmented Virtuality](#augmented-virtuality), [Mixed Reality](#mixed-reality)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Extended Reality](#extended-reality)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Augmented Virtuality</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(AV, Augmentierte Virtualität)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Teils virtuelle Umgebung, in der reale Inhalte eingefügt werden. Dabei werden Informationen aus der realen Welt, wie z. B. Objekte oder Personen, in eine virtuelle Welt integriert.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Augmented Reality](#augmented-reality), [Virtual Reality](#virtual-reality), [Immersion](#immersion), [Mixed Reality](#mixed-reality)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#xr">XR</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Balanced Scorecard</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(BSC)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ganzheitlich orientiertes Konzept zur Messung, Dokumentation und Steuerung der Aktivitäten einer Organisation in Bezug auf ihre Vision und Strategie. Sie kombiniert Indikatoren aus verschiedenen Perspektiven und fördert dadurch die Transparenz sowie die strategische Ausrichtung der Organisation.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Vision](#vision)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bedarfsanalyse</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(Bedarfsermittlung)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ermittelt systematisch Lücken und künftige Handlungsfelder in einem Themenfeld, einer Organisation oder einer Zielgruppe. Basierend darauf werden ziel- und themenorientierte Maßnahmen entwickelt und nachfrageorientiert angeboten.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Transformationsnetzwerk](#transformationsnetzwerk), [Prospektive Evaluation](#prospektive-evaluation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Begleitforschung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Wissenschaftliche Arbeit mit dem Ziel, Daten und Informationen zu gewinnen, die es erlauben, Wirksamkeit und Nutzen von (Modell-)Projekten oder Programmen abzuschätzen. Dadurch können diese bei Bedarf transferiert, geändert oder beendet werden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Wissenstransfer](#wissenstransfer), [Wissenserzeugung](#wissenserzeugung), [Formative Evaluation](#formative-evaluation), [Impact](#impact), [Indikator](#indikator)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Wissenschaft](#wissenschaft)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wirkung">Wirkung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Berufliche Weiterbildung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Erwerben von zusätzlichen Fähigkeiten nach der Ausbildung. Entweder, um bestehendes Wissen zu vertiefen und zu aktualisieren (Fortbildung), sich auf eine höhere Position vorzubereiten (Aufstiegsweiterbildung) oder eine neue berufliche Richtung einzuschlagen (Umschulung).</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Fortbildung](#fortbildung), [Wissenschaftliche Weiterbildung](#wissenschaftliche-weiterbildung), [Betriebliche Weiterbildung](#betriebliche-weiterbildung), [Allgemeine Weiterbildung](#allgemeine-weiterbildung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Best Practices</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Praktiken, Methoden und Verhaltensweisen, die in der Praxis zum Einsatz kommen und erprobt, verbreitet und (besonders) positiv evaluiert sind.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">In der Praxis erprobte, verbreitete und positiv evaluierte Praktiken, Methoden und Verhaltensweisen</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Next Practices](#next-practices)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Betriebliche Weiterbildung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Organisierte und vollständig oder teilweise von dem\*der Arbeitgeber\:in finanzierte Weiterbildungsmaßnahmen in unterschiedlichen Lernformaten (Lernvideos, digitale oder analoge Workshops, Hackathons, Barcamps etc.)</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Berufliche Weiterbildung](#berufliche-weiterbildung), [Wissenschaftliche Weiterbildung](#wissenschaftliche-weiterbildung), [Allgemeine Weiterbildung](#allgemeine-weiterbildung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#weiterbildung">Weiterbildung</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bevölkerungsschutz</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Oberbegriff für alle Aufgaben und Maßnahmen der Kommunen und der Länder im Katastrophenschutz sowie des Bundes im Zivilschutz</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Schutzgut](#schutzgut)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bewältigungskapazität</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Die Kombination aller Stärken, Eigenschaften und Ressourcen, die innerhalb einer Organisation, Gemeinschaft oder Gesellschaft vorhanden sind. Dadurch können Katastrophenrisiken bewältigt und verringert und die Widerstandsfähigkeit gestärkt werden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Resilienz](#resilienz), [Risiko](#risiko), [Katastrophe](#katastrophe), [Härtung](#härtung), [Risikomanagement](#risikomanagement), [Katastrophenschutz](#katastrophenschutz)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagement">Risikomanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bildung für Nachhaltige Entwicklung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(BNE)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Befähigt Menschen zu zukunftsfähigem Denken und Handeln, indem sie es ermöglicht, die Auswirkungen des eigenen Handelns auf die Welt zu verstehen. Sie berücksichtigt dabei explizit planetare Grenzen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Sozial-ökologische Transformation](#sozial-ökologische-transformation), [Transformatives Lernen](#transformatives-lernen), [Nachhaltigkeit](#nachhaltigkeit)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Biodiversitätskorridor</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Viele einzelne naturnahe/natürliche Flächen bilden an Orten mit wenig Natur und Grün einen Korridor. Über diesen Korridor und zwischen den einzelnen naturnahen/natürlichen Flächen können Lebewesen migrieren.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Renaturierung](#renaturierung), [Revitalisierung](#revitalisierung), [Grün-blaue Infrastruktur](#grün-blaue-infrastruktur), [Grüne Infrastruktur](#grüne-infrastruktur), [Naturbasierte Lösung](#naturbasierte-lösung), [Fassadenbegrünung](#fassadenbegrünung), [Dachbegrünung](#dachbegrünung), [Extensive Dachbegrünung](#extensive-dachbegrünung), [Naturnahe Flächen](#naturnahe-flächen), [Natürliche Fläche](#natürliche-fläche)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Blackout</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Ungeplanter, großflächiger und lang anhaltender Stromausfall</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Extremereignis](#extremereignis)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kritis">KRITIS</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kritis">KRITIS</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Blau-grüne Infrastruktur</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(BGI)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Strategisch geplantes Netzwerk natürlicher/naturnaher Flächen mit Schwerpunkt Wasserabfluss und Wechselwirkungen mit natürlichem und technischem Wasserkreislauf. Ziele sind Trockenheits- und Hochwasservorsorge, Verbesserung der Wasserqualität sowie ökologische und gesundheitliche Aufwertung.  Elemente sind u. a. Retentionssysteme, Zisternen, Rigolen, urbane Gewässer, Regengärten und Gründächer.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">Dieses Konzept kombiniert Wasserbewirtschaftung (blau) mit Vegetation (grün), um nachhaltige und resiliente städtische und ländliche Umgebungen zu schaffen.</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Interdependenz](#interdependenz), [Ökosystemdienstleistungen](#ökosystemdienstleistungen), [Ökosystemfunktion](#ökosystemfunktion), [Blaue Infrastruktur](#blaue-infrastruktur), [Grün-blaue Infrastruktur](#grün-blaue-infrastruktur), [Grüne Infrastruktur](#grüne-infrastruktur), [Natürliche Fläche](#natürliche-fläche)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Infrastruktur](#infrastruktur), [Naturbasierte Lösung](#naturbasierte-lösung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Blaue Infrastruktur</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Netzwerk aus wassergeprägten Elementen, die eine Vielzahl von ökologischen, sozialen und wirtschaftlichen Funktionen erfüllen. Strategisch werden diese z. B. zur Bewältigung von Problemen im Wasserkreislauf (wie Wasseraufbereitung, Dürren oder Regenwasserbewirtschaftung) angelegt. Natürliche Systeme sind u. a. Seen oder Flüsse; geplante Systeme umfassen Retentionsflächen oder Flussrenaturierungen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">Wasserbezogene Infrastruktur</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Blau-grüne Infrastruktur](#blau-grüne-infrastruktur), [Interdependenz](#interdependenz), [Ökosystemdienstleistungen](#ökosystemdienstleistungen), [Ökosystemfunktion](#ökosystemfunktion), [Grün-blaue Infrastruktur](#grün-blaue-infrastruktur), [Grüne Infrastruktur](#grüne-infrastruktur), [Natürliche Fläche](#natürliche-fläche)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Bodengebundene Fassadenbegrünung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(Bodengebundene Begrünung)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Begrünung durch Kletterpflanzen, welche in den Boden oder in Kübel direkt vor der Wand gepflanzt werden. Sie wachsen entweder direkt an der Wand hinauf oder werden durch Rankhilfen unterstützt.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Wandgebundene Fassadenbegrünung](#wandgebundene-fassadenbegrünung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Grün-blaue Infrastruktur](#grün-blaue-infrastruktur), [Grüne Infrastruktur](#grüne-infrastruktur), [Naturbasierte Lösung](#naturbasierte-lösung), [Fassadenbegrünung](#fassadenbegrünung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Change Agents</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Personen(-gruppen), die aktiv Veränderungen initiieren oder bestehende Prozesse hinterfragen und als Vorreiter\:innen und Transformationsbeschleuniger\:innen für Stakeholder des Reallabors fungieren.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Reallabor](#reallabor), [Transformative Wissenschaft](#transformative-wissenschaft), [Stakeholder](#stakeholder), [Green Skills](#green-skills), [Transformation](#transformation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Sozial-ökologische Transformation](#sozial-ökologische-transformation), [Sustainable Development Goals](#sustainable-development-goals)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#transformation">Transformation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Citizen Science</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Direkte Beteiligung von Bürger\:innen am Forschungsprozess, beispielsweise beim Sammeln, Auswerten und Aufbereiten von Daten. Der Fokus liegt hierbei auf der aktiven Gestaltung und Umsetzung von Wissenschaft durch Bürger\:innen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Partizipation](#partizipation), [Wissenserzeugung](#wissenserzeugung), [Partizipative Wissenschaftskommunikation](#partizipative-wissenschaftskommunikation), [Co-kreative Wissenschaftskommunikation](#co-kreative-wissenschaftskommunikation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-Design</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Aktive und methodengeleitete Einbindung relevanter Stakeholdergruppen in den Forschungs- und Entwicklungsprozess</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-cl-definition-label">Einfache Beschreibung: </span> **
# <span class="gloss-term-all gloss-cl-definition">Sinnvolle Einbindung verschiedener Stakeholder in Prozesse. Dies passiert methodengeleitet und bewusst, unterstützt durch schrittweise Reevaluation und Anpassung gemeinsam mit relevanten Personen(-gruppen). Um seinem Anspruch gemäß sinnvoll zu sein, muss Co-Design stark kontext-angepasst vorgehen: Einzelne Elemente variieren je nach Stakeholder, Situation, Ort, Ressourcen, etc..</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Transformationsnetzwerk](#transformationsnetzwerk), [Reallabor](#reallabor), [Partizipation](#partizipation), [Stakeholder](#stakeholder), [Dialoggruppe](#dialoggruppe), [Zielgruppe](#zielgruppe), [Partizipative Wissenschaftskommunikation](#partizipative-wissenschaftskommunikation), [Co-kreative Wissenschaftskommunikation](#co-kreative-wissenschaftskommunikation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Co-Kreation](#co-kreation)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-Kreation</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Gemeinschaftliche Gestaltung eines End- oder Zwischenprodukts unter Einbezug relevanter Stakeholdergruppen</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Transfermodus 2a](#transfermodus-2a), [Transfermodus 2b](#transfermodus-2b), [Stakeholder](#stakeholder), [Dialoggruppe](#dialoggruppe), [Entwicklungsteam](#entwicklungsteam), [Co-kreative Wissenschaftskommunikation](#co-kreative-wissenschaftskommunikation), [Realexperiment](#realexperiment), [Output](#output)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Co-Site</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ...
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#kommunikation">Kommunikation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wissenserzeugung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Prozess, mit dem neues Wissen generiert wird. Wissen kann auf verschiedenen Wegen erzeugt werden, z. B. durch Forschung und partizipativen Austausch. Im Kontext von Reallaborarbeit bedeutet dies u. a. die Verknüpfung von vorhandenem Wissen verschiedener relevanter Stakeholder und die dadurch erzeugte ganzheitliche Erweiterung, Ergänzung und Entwicklung neuen Wissens.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Wissenschaft](#wissenschaft), [Wissenstransfer](#wissenstransfer), [Transfer](#transfer), [Reallabor](#reallabor), [Partizipation](#partizipation), [Citizen Science](#citizen-science), [Transformatives Lernen](#transformatives-lernen), [Transformative Wissenschaft](#transformative-wissenschaft), [Workshop](#workshop), [Realexperiment](#realexperiment), [Begleitforschung](#begleitforschung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Wissenstransfer</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Austausch von Wissen zwischen Personen oder Institutionen, z. B. in der Gesellschaft, Politik, Wirtschaft oder Wissenschaft</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Wissenschaftskommunikation](#wissenschaftskommunikation), [Transfer](#transfer), [Transformative Wissenschaft](#transformative-wissenschaft), [Klimakommunikation](#klimakommunikation), [Wissenserzeugung](#wissenserzeugung), [Workshop](#workshop), [Realexperiment](#realexperiment), [Begleitforschung](#begleitforschung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Wissenschaft](#wissenschaft)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Workshop</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Methodisch strukturiertes Setting der Zusammenarbeit mehrerer Personen, welches zumeist von einer Moderation geleitet wird. Ziele sind die begleitete Wissensaneignung oder gemeinsame Produktion von Inhalten sowie Prototypen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Wissenstransfer](#wissenstransfer), [Prototyp](#prototyp), [Lernsettings](#lernsettings), [Wissenserzeugung](#wissenserzeugung), [Co-kreativer Workshop](#co-kreativer-workshop), [Output](#output)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#partizipation">Partizipation</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zeitliche Auflösung</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Zeitliche Abstände zwischen einzelnen Aufnahmen des gleichen Gebietes in einem Datensatz</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Zeitreihe](#zeitreihe), [Räumliche Auflösung](#räumliche-auflösung), [Datenvisualisierung](#datenvisualisierung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zeitreihe</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Zeitlich geordnete Messdaten, die regelmäßig erfasst wurden.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Zeitliche Auflösung](#zeitliche-auflösung), [Datenerfassung](#datenerfassung)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#daten">Daten</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zielgruppe</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Eine Person oder Gruppe von Menschen, die mit den Maßnahmen des Reallabors angesprochen oder eingebunden werden sollen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Co-Design](#co-design), [Partizipation](#partizipation), [Stakeholder](#stakeholder), [Dialoggruppe](#dialoggruppe), [Partizipative Wissenschaftskommunikation](#partizipative-wissenschaftskommunikation), [Outcome](#outcome)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#projekt">Projekt</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zielwissen</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Gemeinsam generiertes Wissen über gewünschte zukünftige Entwicklungen eines Systems</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Best Practices](#best-practices), [Vision](#vision), [Systemwissen](#systemwissen), [Transformationswissen](#transformationswissen)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#wissensmanagement">Wissensmanagement</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Zivilschutz</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Schutz der Bevölkerung durch nicht militärische Maßnahmen im Falle von militärischen Auseinandersetzungen. Zum Zivilschutz gehören insbesondere der Selbstschutz, die Warnung der Bevölkerung, der Schutzbau, die Aufenthaltsregelung, der Katastrophenschutz nach Maßgabe des § 11 ZSKG, Maßnahmen zum Schutz der Gesundheit oder von Kulturgut.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Schutzgut](#schutzgut), [Katastrophenschutz](#katastrophenschutz)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span class="gloss-term-all gloss-subclass-tag gloss-subclass-label">Unterbegriff von: </span> **
# <span class="gloss-term-all gloss-subCategoryOf">[Bevölkerungsschutz](#bevölkerungsschutz)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagment">Risikomanagment</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#risikomanagment">Risikomanagment</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Ökosystemdienstleistungen</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# **<span style="display: inline-flex" class="gloss-term-all gloss-acronym">(Ökosystemleistung)</span>**
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Leistungen, die ein Ökosystem dem Menschen bereitstellt. Sie sind entscheidend für das menschliche Wohlbefinden und die nachhaltige Entwicklung. Dabei können sie regulierender (z. B. Klimaregulierung, Bestäubung), unterstützender (z. B. Bodenbildung, Nährstoffkreislauf), kultureller (z. B. Erholung, Tourismus) und versorgender (z. B. Nahrung, Wasser) Natur sein.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Blau-grüne Infrastruktur](#blau-grüne-infrastruktur), [Klimaanpassung](#klimaanpassung), [Renaturierung](#renaturierung), [Revitalisierung](#revitalisierung), [Rekultivierung](#rekultivierung), [Nachhaltigkeit](#nachhaltigkeit), [Ökosystemfunktion](#ökosystemfunktion), [Klimawandelanpassung](#klimawandelanpassung), [Blaue Infrastruktur](#blaue-infrastruktur), [Grün-blaue Infrastruktur](#grün-blaue-infrastruktur), [Grüne Infrastruktur](#grüne-infrastruktur), [Naturbasierte Lösung](#naturbasierte-lösung), [Naturnahe Flächen](#naturnahe-flächen)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
#
# ### <span style="display: inline-flex" class="gloss-term-all gloss-term">Ökosystemfunktion</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# <span class="gloss-term-all gloss-definition">Alle physikalischen, chemischen und biologischen Prozesse, die in einem Ökosystem stattfinden und dessen Selbsterhaltung und Entwicklung sicherstellen.</span>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
# ::: {.content-visible when-format="html"}
# **<span class="gloss-term-all gloss-status-label">Status: </span> **
# <span class="gloss-term-all gloss-status">Entwurf</span>
# <br>
#
# :::
#
# **<span class="gloss-term-all gloss-similar-tag gloss-similar-label">Verwandt: </span> **
# <span class="gloss-term-all gloss-similarto">[Blau-grüne Infrastruktur](#blau-grüne-infrastruktur), [Ökosystemdienstleistungen](#ökosystemdienstleistungen), [Blaue Infrastruktur](#blaue-infrastruktur), [Grün-blaue Infrastruktur](#grün-blaue-infrastruktur), [Grüne Infrastruktur](#grüne-infrastruktur), [Naturbasierte Lösung](#naturbasierte-lösung), [Naturnahe Flächen](#naturnahe-flächen), [Natürliche Fläche](#natürliche-fläche)</span>
# <br>
#
# ```{=latex}
# \nopagebreak
# \penalty 100000
# ```
#
#
# ::: {.content-visible when-format="html"}
# <span class="tag-label">Tags:</span>
# <span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>
# :::
#
# ::: {.content-visible when-format="pdf"}
# *<span class="gloss-term-all gloss-tag"><a href="/cosite002.html#gbi">GBI</a></span>*
# :::
#
#
# ---
#
# ```{=latex}
# \penalty -100
# ```
#
#
# </body></html>
